# %%
import matplotlib.pyplot as plt
import requests
from scipy import stats
import json
import pandas as pd
import csv

from pprint import pprint

# %%
url = "https://zillow56.p.rapidapi.com/search"

querystring = {"location":"houston, tx"}

headers = {
    "X-RapidAPI-Key": "330fa30182msh4cc99339b202368p1e5532jsnc6ebcb5a8540",
    "X-RapidAPI-Host": "zillow56.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'results': [{'bathrooms': 3.0, 'bedrooms': 3.0, 'city': 'Humble', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': 0, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'SINGLE_FAMILY', 'imgSrc': 'https://photos.zillowstatic.com/fp/3abaaba0b8f736bca740f97b26bcc3e7-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isRentalWithBasePrice': True, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 30.063204, 'listing_sub_type': {'is_forAuction': True}, 'livingArea': 2594.0, 'longitude': -95.199455, 'lotAreaUnit': 'sqft', 'lotAreaValue': 10018.8, 'price': 0.0, 'priceForHDP': 0.0, 'rentZestimate': 2400, 'shouldHighlight': False, 'state': 'TX', 'streetAddress': '2414 Brookdale Dr', 'taxAssessedValue': 302352.0, 'zestimate': 365800, 'zipcode': '77339', 'zpid': 28416488}, {'bathrooms': 0.0, 'city': 'Houston', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': 0, 
# ...

# %%
import requests

url = "https://real-estate-data.p.rapidapi.com/housing_prices/state"

querystring = {"page":"1"}

headers = {
    "X-RapidAPI-Key": "330fa30182msh4cc99339b202368p1e5532jsnc6ebcb5a8540",
    "X-RapidAPI-Host": "real-estate-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'page': 1, 'page_size': 100, 'total_amount': 52, 'total_pages': 1, 'data': [{'RegionID': '9', 'SizeRank': '0', 'RegionName': 'California', 'RegionType': 'state', 'StateName': '', '2000-01-31': '190427.37635853596', '2000-02-29': '191067.45960946643', '2000-03-31': '191931.7287363912', '2000-04-30': '193807.7993113002', '2000-05-31': '195988.44874131176', '2000-06-30': '198341.36314165243', '2000-07-31': '200826.20880868103', '2000-08-31': '203420.51889877513', '2000-09-30': '206020.84941571043', '2000-10-31': '208486.8064374424', '2000-11-30': '210915.30653101965', '2000-12-31': '213292.06790747575', '2001-01-31': '215302.6910632799', '2001-02-28': '217290.7842075519', '2001-03-31': '219528.54700728573', '2001-04-30': '222310.90137927572', '2001-05-31': '225099.0161187298', '2001-06-30': '227631.7877035189', '2001-07-31': '230003.03375216332', '2001-08-31': '232287.7647600727', '2001-09-30': '234505.31025618932', '2001-10-31': '236578.76303056147', '2001-11-30': '238526.64171960988'
# ...
